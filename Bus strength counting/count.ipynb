# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ikETQ1XPUZVXd9IMdFnL")
project = rf.workspace("projects-7babi").project("yolo8-human-head-detection-huykl")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 115.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Yolo8-Human-head-detection--1 in yolov8:: 100%|██████████| 2604/2604 [00:00<00:00, 5602.76it/s]

# %%
model.train(data='/content/Yolo8-Human-head-detection--1/data.yaml', batch = 15, epochs = 15, imgsz = 640)
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image('/content/runs/detect/train/confusion_matrix.png')

# %%
Image('/content/runs/detect/train/results.png')

# %%
check = model.predict('/content/Yolo8-Human-head-detection--1/test/images/870e6365ad3c4bd2_jpg.rf.06b04aa57676babb1ab1113e598c3fde.jpg')
check[0].show()
# Out:
# image 1/1 /content/Yolo8-Human-head-detection--1/test/images/870e6365ad3c4bd2_jpg.rf.06b04aa57676babb1ab1113e598c3fde.jpg: 640x640 7 Human-heads, 36.1ms
# Speed: 2.1ms preprocess, 36.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
check = model.predict('/content/Yolo8-Human-head-detection--1/test/images/de66c586e7127545_jpg.rf.5d96ff026fd349f2995cbe102f2d373e.jpg')
check[0].show()
# Out:
# image 1/1 /content/Yolo8-Human-head-detection--1/test/images/de66c586e7127545_jpg.rf.5d96ff026fd349f2995cbe102f2d373e.jpg: 640x640 1 Human-head, 36.8ms
# Speed: 2.8ms preprocess, 36.8ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
metrics = model.val(
    data="/content/Yolo8-Human-head-detection--1/data.yaml",
    split="test",
    plots=True
)
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1700.1±454.9 MB/s, size: 68.4 KB)
# val: Scanning /content/Yolo8-Human-head-detection--1/test/labels... 122 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122 2299.8it/s 0.1s
# val: New cache created: /content/Yolo8-Human-head-detection--1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.9it/s 4.8s
#                    all        122        730      0.578      0.458      0.494      0.261
# Speed: 1.5ms preprocess, 22.9ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to runs/detect/train2

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
video_path = "/content/busy-food-shop-in-melbourne-market-SBV-352536536-preview.mp4"

results = model.predict(
    source=video_path,
    show=False,
    save=True,
    save_txt=False,
    conf=0.4,
    imgsz=640,
    tracker="botsort.yaml"
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/269) /content/busy-food-shop-in-melbourne-market-SBV-352536536-preview.mp4: 384x640 6 Human-heads, 46.9ms
# video 1/1 (frame 2/269) /content/busy-food-shop-in-melbourne-market-SBV-352536536-preview.mp4: 384x640 6 Human-heads, 24.7ms
# video 1/1 (frame 3/269) /content/busy-food-shop-in-melbourne-market-SBV-352536536-preview.mp4: 384x640 6 Human-heads, 24.5ms
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')
